# %% [markdown]
# # Probability distribution problems

# %% [markdown]
# ## Binomial distribution
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment; for example, when you flip a coin, it can be either head or tails.

# %%
from scipy.stats import binom

# Define all the probability functions related to this distribution

def dbinom(x, size, prob = 0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Generates random variables from the binomial distribution
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Binomial(10, 0.2) distribution, where n = 10 is the number of trials and p = 0.2 is the probability of success in a single trial
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Exercise 1
#
# Write the above functions but for both normal and uniform distributions.

# %%
from scipy.stats import norm


def dnorm(x, mean=0, std=1):
    """
    Calculates the point estimate of the normal distribution (PDF)
    """
    result = norm.pdf(x, loc=mean, scale=std)
    return result

def pnorm(q, mean=0, std=1):
    """
    Calculates the cumulative distribution function of the normal distribution
    """
    result = norm.cdf(q, loc=mean, scale=std)
    return result

def qnorm(p, mean=0, std=1):
    """
    Calculates the quantile function (inverse CDF) of the normal distribution
    """
    result = norm.ppf(p, loc=mean, scale=std)
    return result

def rnorm(n, mean=0, std=1):
    """
    Generates random variables from the normal distribution
    """
    result = norm.rvs(loc=mean, scale=std, size=n)
    return result

# %%
from scipy.stats import uniform

# Define all the probability functions related to the uniform distribution

def duniform(x, low=0, high=1):
    """
    Calculates the point estimate of the uniform distribution (PDF)
    """
    result = uniform.pdf(x, loc=low, scale=high - low)
    return result

def puniform(q, low=0, high=1):
    """
    Calculates the cumulative distribution function of the uniform distribution
    """
    result = uniform.cdf(q, loc=low, scale=high - low)
    return result

def quniform(p, low=0, high=1):
    """
    Calculates the quantile function (inverse CDF) of the uniform distribution
    """
    result = uniform.ppf(p, loc=low, scale=high - low)
    return result

def runiform(n, low=0, high=1):
    """
    Generates random variables from the uniform distribution
    """
    result = uniform.rvs(loc=low, scale=high - low, size=n)
    return result

# %%
np.random.seed(42)

# Normal(0, 1) distribution, mean = 0, std = 1
print(f"Probability that a Normal(0, 1) takes the value 0: {dnorm(0, mean=0, std=1)}")
print(f"Probability that a Normal(0, 1) will take a value less than 0: {pnorm(0, mean=0, std=1)}")
print(f"Which value of a Normal(0, 1) has a cumulative probability of 0.9? {qnorm(0.9, mean=0, std=1)}")
print(f"Generate 2000 random values from a Normal(0, 1) distribution: {rnorm(2000, mean=0, std=1)}")
# Out:
# Probability that a Normal(0, 1) takes the value 0: 0.3989422804014327
# Probability that a Normal(0, 1) will take a value less than 0: 0.5
# Which value of a Normal(0, 1) has a cumulative probability of 0.9? 1.2815515655446004
# Generate 2000 random values from a Normal(0, 1) distribution: [ 0.49671415 -0.1382643   0.64768854 ... -0.88187465 -0.16306696
#  -0.74490264]

# %%
np.random.seed(42)

# Uniform(0, 1) distribution, low = 0, high = 1
print(f"Probability that a Uniform(0, 1) takes the value 0.5: {duniform(0.5, low=0, high=1)}")
print(f"Probability that a Uniform(0, 1) will take a value less than 0.5: {puniform(0.5, low=0, high=1)}")
print(f"Which value of a Uniform(0, 1) has a cumulative probability of 0.9? {quniform(0.9, low=0, high=1)}")
print(f"Generate 2000 random values from a Uniform(0, 1) distribution: {runiform(2000, low=0, high=1)}")
# Out:
# Probability that a Uniform(0, 1) takes the value 0.5: 1.0
# Probability that a Uniform(0, 1) will take a value less than 0.5: 0.5
# Which value of a Uniform(0, 1) has a cumulative probability of 0.9? 0.9
# Generate 2000 random values from a Uniform(0, 1) distribution: [0.37454012 0.95071431 0.73199394 ... 0.06895802 0.05705472 0.28218707]

# %%
import matplotlib.pyplot as plt

# Data for plotting
data = rnorm(2000, mean=0, std=1)

pdf = dnorm(data, mean=0, std=1)
cdf = pnorm(data, mean=0, std=1)
ppf = qnorm(data, mean=0, std=1)

fig, axis = plt.subplots(3, 1, figsize=(5, 7))

axis[0].stem(data, pdf, 'r-', basefmt=" ")
axis[1].stem(data, cdf, 'b-', basefmt=" ")
axis[2].stem(data, ppf, 'g-', basefmt=" ")

plt.tight_layout()
plt.show()

# %%
# Data for plotting
data = runiform(2000, low=0, high=1)

pdf = duniform(data, low=0, high=1)
cdf = puniform(data, low=0, high=1)
ppf = quniform(data, low=0, high=1)

fig, axis = plt.subplots(3, 1, figsize=(5, 7))

axis[0].stem(data, pdf, 'r-', basefmt=" ")
axis[1].stem(data, cdf, 'b-', basefmt=" ")
axis[2].stem(data, ppf, 'g-', basefmt=" ")

plt.tight_layout()
plt.show()
